# %%
import numpy as np

# %%
# def union(a,b):
# #     A1 = np.array(tall, dtype= 'float64')
# #     A2 = np.array(short, dtype= 'float64')
#     t = []
#     for i in range (len(a)):
#         if (a[i][1] > b[i][1]):
#             t.append(a[i])
# #             new_arr = np.append(t, A1[i])

#         elif (b[i][1] > a[i][1]):
#             t.append(b[i])
# #             new_arr = np.append(t, A2[i])
#     print ('The uion of the given fuzzy sets is: ',t)
        
# #     return np.maximum(A1[0][1],A2[0][1])

# def intersection(a1,b1):
#     c = []
            
#     for i in range (len(a1)):
#         if (a1[i][0] == b1[i][0]):
#             if (a1[i][1] < b1[i][1]):
#                 c.append(a1[i])
# #             new_arr = np.append(t, A1[i])

#             elif (b1[i][1] < a1[i][1]):
#                 c.append(b1[i])
# #             new_arr = np.append(t, A2[i])
#     print ('The intersection of the given fuzzy sets is: ',c)
    
# def subset (s1,s2):
#     sub = []
#     for n in range (len(s1)):
#         if (float(s1[n][1]) <= float(s2[n][1])):
#             sub.append(s1[n])
#         else:
#             sub = sub
#     print ('The subset of the given fuzzy sets: ',sub)
    
    
# def alpha (al):
#     alp = []
#     alpha_value = input('Enter the value of alpha: ')
#     if (float(alpha_value) >=0) and (float(alpha_value) <= 1):
#         for i in range (len(al)):
#             if (float(al[i][1]) >= float(alpha_value)):
#                 alp.append(al[i])
#             else:
#                 pass
#     else:
#         print ('The value of alpha is invalid.')
    
#     print ('The required set after alpha cut: ', alp)
    
# def complement (u):
#     num_arr = np.array(u, dtype = 'float64')
#     d = np.array(u, dtype = 'float64')[0:,1:]
#     membership_values = 1 - d
#     # print (num_arr[0:,1])
#     # print ((num_arr[0:,1]).shape)
#     # print ('Before reshaping: ',membership_values)
#     # # print (membership_values.shape.reshape(3,))
#     # print ('After reshaping: ',membership_values.reshape(3,))
#     num_arr[0:,1] = membership_values.reshape(3,)
#     print(num_arr)
    
#     com = []
#     for i in range (u):
        
        
#     print (type(membership_values))
    
    # com = []
    # # for i in range (len(u)):
    # #     #round(my_float, 2)
    # #     d1[i][1].replace(d1[i][1], round((1.0 - float(d1[i][1])),2))
    # com_np = np.unique(np.append(com,(np.ones(3, dtype = 'float64') - d)))
    # print (com_np)
        # com.append(round((1.0 - float(d1[i][1])),2))
        # d1[i][1] = com [i]
    #print ('The complement of given fuzzy set: ',d1)
    
def height (f1):
    d = np.array(f1, dtype = 'float64')[0:,1:]
    return np.amax(d)

def core (f2):
    c = []
    for i in range (len(f2)):
        if (float(f2[i][1]) == 1.0):
            c.append (f2[i][0])
        else:
            c = c
    return c

def support (f3):
    s = []
    for i in range (len(f3)):
        if (float(f3[i][1]) > 0.0):
            s.append (f3[i][0])
        else:
            s = s
    return s

def boundary (f4):
    b = []
    for i in range (len(f4)):
        if (float(f4[i][1]) > 0.0) and (float(f4[i][1]) < 1.0):
            b.append (f4[i][0])
        else:
            b = b
    return b

# %%
tall = [['6', '0.8'], ['7', '1'], ['5', '0.1']]
short = [['6', '0.2'], ['7', '0.1'], ['5', '0.9']]

print ('The list of tall fuzzy set1: ',tall)

# A1 = np.array(tall)
# A2 = np.array(short)

# t = []
# for i in range (len(A1)):
#     if (A1[i][1] > A2[i][1]):
#         new_arr = np.append(t, A1[i])
#     elif (A2[i][1] > A1[i][1]):
#         new_arr = np.append(t,A2[i])
#     print (new_arr)
        
        
#print (A1[0][1])

# tall_crisp_set = [1,0,0]
# short_crisp_set = [0,1,1]

# T = np.array(tall_crisp_set)
# S = np.array(short_crisp_set)


# print (np.maximum(T,S))

# intersection_set = intersection(tall_crisp_set,short_crisp_set)
# print (intersection_set.shape)
# sub_set = subset(tall_crisp_set,short_crisp_set)
# sub_set = list(map(int, sub_set))
# union(tall,short)
# intersection(tall,short)
# subset(tall,short)
# alpha(tall)
# complement(tall)
# # complement(short)
# print ('The list of tall fuzzy set2: ',tall)
# complement(short)
#print ('Intersection is ',intersection(tall_crisp_set,short_crisp_set))
print ('Height of the given fuzzy set: ', height(tall))
print ('The core of the given fuzzy set: ', core(tall))
print ('The support of the given fuzzy set: ', support(tall))
print ('The boundary of the given fuzzy set: ', boundary(tall))
#print (I)

# print (T)
# print (S)
# Out:
# The list of tall fuzzy set1:  [['6', '0.8'], ['7', '1'], ['5', '0.1']]
# Height of the given fuzzy set:  1.0
# The core of the given fuzzy set:  ['7']
# The support of the given fuzzy set:  ['6', '7', '5']
# The boundary of the given fuzzy set:  ['6', '5']

# %%
ans = [[6, 0.8], 
       [7, 0.9], 
       [5, 0.1]]

ans_np = np.array(ans)
ans_np[0:,1:]
# Out:
# array([[0.8],
#        [0.9],
#        [0.1]])
